# %% [markdown]
# [All the news](https://components.one/datasets/#all-the-news)
# 143,000 articles from 15 American publications

# %%
import gensim
gensim.models.doc2vec.FAST_VERSION
# Out:
# 1

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from collections import namedtuple
from corpus_builder import CorpusBuilder
import csv
import os
import sys
from tqdm import tqdm
from util import MALLET_PATH, show_topic_model

csv.field_size_limit(sys.maxsize)
# Out:
# 131072

# %%
# This data is availble at 
path = './data/all-the-news/all_the_news_v2.csv'

# %%
Article = namedtuple('Article', 'id, title, author, date, content, year, month, publication, url, length'.split(', '))

# %%
articles = []
with open(path, mode='r', encoding='UTF-8') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    err_count = 0
    for row in csv_reader:
        if line_count == 0:
            #print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            try:
                row = [cell.strip() for cell in row]
                id, title, author, date, content, year, month, publication, url, length = row
                year = int(year[:-2])
                month = int(month[:-2])
                length = int(length[:-2])
                article = Article(id, title, author, date, content, year, month, publication, url, length)
                articles.append(article)
                #print("%s\nBY %s ON %s\n%s" % (title, author, date, content[:200]))
            except ValueError as ex:
                #print("%d. <<%s>>" % (line_count, row))
                err_count += 1
                # raise ex
            line_count += 1
    print(f'Processed {line_count} lines with {err_count} errors.')
# Out:
# Processed 146151 lines with 6777 errors.

# %%
year2freq = {}
for article in tqdm(articles):
    if article.year not in year2freq: year2freq[article.year] = 0
    year2freq[article.year] += 1
# Out:
# 100%|██████████| 139373/139373 [00:00<00:00, 1165374.31it/s]

# %%
year2freq
# Out:
# {2000: 1,
#  2003: 2,
#  2004: 1,
#  2005: 2,
#  2007: 1,
#  2008: 2,
#  2009: 3,
#  2010: 5,
#  2011: 7,
#  2012: 27,
#  2013: 452,
#  2014: 2579,
#  2015: 7986,
#  2016: 79396,
#  2017: 48909}

# %%
texts = [article.content for article in articles if article.year == 2016 or article.year == 2017]

# %%
# %%time

DATA_DIRECTORY = './data/all-the-news'
MODEL_DIRECTORY = './model/all-the-news'
REFRESH = True

builder = CorpusBuilder(
    ndocs=len(texts),
    phrase_min_count=10, 
    vocabulary_size=50000,
    bigram_min_count=5,
    bigram_threshold=10,
    trigram_min_count=5,
    trigram_threshold=10,
    data_directory=DATA_DIRECTORY,
    model_directory=MODEL_DIRECTORY
)
if REFRESH:
    builder.train_phrasers(texts)    
    builder.save_phrasers()
    prepared_texts = builder.prepare_texts(texts)
    builder.build_vocabulary(prepared_texts, save=True)
    corpus = builder.build_corpus(prepared_texts)
    builder.build_dictionary(corpus, save=True)
builder.load_phrasers()
builder.load_vocabulary()
builder.load_dictionary()
encoded_corpus = builder.encode_corpus(corpus)
# Out:
#   0%|          | 4/128305 [00:00<1:08:59, 31.00it/s]
# Streaming sentences.
# 100%|██████████| 128305/128305 [21:44<00:00, 98.36it/s]
#   0%|          | 3/128305 [00:00<1:28:04, 24.28it/s]
# Streaming sentences.
# 100%|██████████| 128305/128305 [30:28<00:00, 70.17it/s]
# 100%|██████████| 128305/128305 [25:11<00:00, 84.89it/s]
#   0%|          | 186/128305 [00:00<01:08, 1856.92it/s]
# Building vocabulary over 128305 documents.
# 100%|██████████| 128305/128305 [00:38<00:00, 3367.73it/s]
# 100%|██████████| 128305/128305 [00:25<00:00, 5070.24it/s]
# CPU times: user 1h 25min 26s, sys: 1min 13s, total: 1h 26min 39s
# Wall time: 1h 26min 48s

# %%
# %%time

from gensim.models.wrappers import LdaMallet
from gensim import utils, matutils

num_topics = 128
model = LdaMallet(
    mallet_path=MALLET_PATH, 
    corpus=encoded_corpus,
    num_topics=num_topics, 
    id2word=builder.dictionary
)
# Out:
# CPU times: user 3min 56s, sys: 6.87 s, total: 4min 3s
# Wall time: 55min 56s

# %%
show_topic_model(model, builder.dictionary, use_phrasers=True)
# Out:
# Topic 0:
#   state, states, california, texas, governor, law, virginia, florida, colorado, bill
#   north_carolina, west_virginia, south_carolina, executive_director, new_mexico, rhode_island
# Topic 1:
#   china, chinese, japan, beijing, country, u.s., japanese, kim, taiwan, pyongyang
#   north_korea, south_korea, united_states, hong_kong, north_korean, south_china_sea
# Topic 2:
#   wearing, fashion, wear, dress, hair, wore, clothes, style, shoes, model
#   post_shared_by, t-shirt, t-shirts, photo_posted_by, inspired_by, her_husband
# Topic 3:
#   israel, jewish, israeli, jews, time, palestinians, jerusalem, netanyahu, palestinian, people
#   west_bank, united_states, anti-semitism, two-state_solution, tel_aviv, middle_east
# Topic 4:
#   company, sales, products, customers, market, business, consumers, companies, amazon, price
#   less_than, whole_foods, wal-mart, chief_executive, two_years, e-commerce
# Topic 5:
#   trump, support, vote, republican, president, nominee, romney, party, told, mccain
#   donald_trump, hillary_clinton, republican_nominee, mitt_romney, may_5, paul_ryan
# Topic 6:
#   johnson, green, open, day, made, time, good, walker, shot, play
#   follow_warner_todd_huston, author_at_igcolonel, warnerthuston_or_email, this_week, golf_course, pga_tour
# Topic 7:
#   people, water, storm, snow, officials, fire, expected, area, rain, residents
#   their_homes, national_weather_service, hurricane_matthew, south_carolina, east_coast, all_rights_reserved
# Topic 8:
#   turkey, government, turkish, country, egypt, erdogan, istanbul, military, officials, ankara
#   coup_attempt, turkish_government, mr._erdogan, prime_minister, united_states, middle_east
# Topic 9:
#   people, transgender, year, bathroom, gender, trans, face, time, person, call
#   transgender_people, trans_women, trans_people, even_though, how_much, north_carolina
# Topic 10:
#   team, won, players, win, athletes, game, match, sport, games, sports
#   world_cup, rio_de_janeiro, premier_league, olympic_games, manchester_united, international_olympic_committee
# Topic 11:
#   refugees, people, country, canada, australia, countries, camp, canadian, refugee, government
#   united_states, syrian_refugees, united_nations, south_sudan, last_week, other_countries
# Topic 12:
#   media, news, story, times, article, press, journalists, reporters, reporter, stories
#   new_york_times, washington_post, huffington_post, news_organizations, news_outlets, media_outlets
# Topic 13:
#   technology, system, future, world, make, create, work, human, things, process
#   focused_on, rely_on, interact_with, for_instance, co-founder, focusing_on
# Topic 14:
#   republicans, bill, house, democrats, senate, republican, ryan, vote, members, legislation
#   white_house, capitol_hill, house_speaker_paul_ryan, house_republicans, paul_ryan, this_week
# Topic 15:
#   game, team, season, yankees, mets, baseball, hit, series, play, field
#   last_season, red_sox, major_league_baseball, home_runs, right-hander, at-bats
# Topic 16:
#   voters, democrats, poll, support, republicans, polls, win, won, clinton, race
#   hillary_clinton, donald_trump, 40_percent, exit_polls, mitt_romney, north_carolina
# Topic 17:
#   women, men, woman, female, sex, girls, male, man, gender, girl
#   young_men, young_girls, even_though, gender_equality, young_woman, equal_pay
# Topic 18:
#   people, obamacare, health, insurance, coverage, law, plans, repeal, states, americans
#   affordable_care_act, insurance_companies, tax_credits, medicaid_expansion, health-care, congressional_budget_office
# Topic 19:
#   company, deal, shares, billion, companies, business, investors, stock, sources, revenue
#   chief_executive, on_wednesday, per_share, people_familiar, time_warner, wall_street
# Topic 20:
#   meeting, deal, agreement, meet, talks, agreed, leaders, met, officials, issues
#   on_wednesday, last_week, this_week, both_sides, told_reporters, next_week
# Topic 21:
#   day, time, body, night, sleep, head, hands, hand, face, small
#   an_hour, your_body, filled_with, two_hours, feel_like, 20_minutes
# Topic 22:
#   advertisement, breitbart, bannon, added, news, stated, media, continued, twitter, conservative
#   breitbart_news, follow_him_on, told_breitbart_news, breitbart_news_daily, steve_bannon, on_siriusxm_patriot
# Topic 23:
#   group, members, organization, groups, foundation, money, campaign, support, including, organizations
#   executive_director, on_behalf, last_month, funded_by, focused_on, raise_money
# Topic 24:
#   russia, syria, russian, putin, moscow, assad, aleppo, syrian, ukraine, rebels
#   united_states, russian_president_vladimir, syrian_government, united_nations, vladimir_putin, civil_war
# Topic 25:
#   plane, flight, airport, passengers, aircraft, air, travel, flying, airline, fly
#   air_force, coast_guard, international_airport, crew_members, flight_attendant, american_airlines
# Topic 26:
#   left, conservatives, conservative, political, liberal, isn, liberals, americans, american, fact
#   related_:, donald_trump, national_review, share_article_on_facebooksharetweet, national_review., left-wing
# Topic 27:
#   jobs, economy, american, trade, u.s., tax, companies, business, country, taxes
#   united_states, economic_growth, american_workers, other_countries, trade_deals, tax_cuts
# Topic 28:
#   immigration, mexico, u.s., immigrants, border, wall, country, mexican, texas, ice
#   united_states, breitbart_texas, illegal_immigrants, undocumented_immigrants, illegal_immigration, illegal_aliens
# Topic 29:
#   uber, car, cars, tesla, drivers, driver, company, vehicles, driving, ford
#   self-driving_cars, model_3, san_francisco, self-driving, general_motors, autonomous_vehicles
# Topic 30:
#   india, people, world, indian, google, make, time, things, light, made
#   new_delhi, united_states, how_much, less_than, questions_about, years_ago
# Topic 31:
#   program, government, funding, money, programs, cost, system, public, federal, support
#   focused_on, food_stamps, long-term, how_much, rely_on, low-income
# Topic 32:
#   claims, claim, made, comments, claimed, fact, public, called, statement, accused
#   last_week, conspiracy_theories, no_evidence, press_conference, an_apology, pointed_out
# Topic 33:
#   gun, guns, people, reach, firearms, radio, advertisement, weapons, nra, twitter
#   second_amendment, awr_hawkins, follow_him_on, political_analyst, breitbart_news, directly_at_awrhawkins
# Topic 34:
#   building, home, house, hotel, property, space, apartment, homes, room, buildings
#   square_feet, owned_by, view_slideshow, his_wife, las_vegas, co-op
# Topic 35:
#   cruz, rubio, campaign, delegates, win, iowa, kasich, candidate, convention, race
#   ted_cruz, new_hampshire, donald_trump, south_carolina, marco_rubio, john_kasich
# Topic 36:
#   rape, people, time, victims, dunn, raped, told, mitchell, country, women
#   sexual_violence, new_orleans, ve_been, united_states, new_york, violence_against
# Topic 37:
#   free, point, serve, meant, work, type, seeking, plans, providing, closing
#   wayback_machine, dig_into, first_stop, be_made_available, internet_archive, path_back
# Topic 38:
#   children, family, parents, mother, kids, child, father, son, home, life
#   her_mother, her_husband, her_daughter, my_father, grew_up, his_wife
# Topic 39:
#   clinton, campaign, sanders, hillary, debate, candidate, democrats, supporters, candidates, democratic
#   hillary_clinton, bernie_sanders, donald_trump, bill_clinton, former_secretary, her_husband
# Topic 40:
#   water, land, park, town, island, river, area, beach, village, road
#   national_park, national_park_service, surrounded_by, filled_with, national_parks, national_monument
# Topic 41:
#   gay, people, orlando, club, mateen, group, lgbt, time, support, make
#   lgbt_people, lgbt_community, sexual_orientation, omar_mateen, same-sex_marriage, marriage_equality
# Topic 42:
#   food, eat, restaurant, eating, make, sugar, made, coffee, restaurants, drink
#   filled_with, peanut_butter, burger_king, fried_chicken, olive_oil, taco_bell
# Topic 43:
#   call, calls, time, called, day, anderson, part, give, people, home
#   more_likely, phone_calls, even_though, phone_call, anything_else, recent_years
# Topic 44:
#   women, abortion, life, woman, health, abortions, pregnancy, baby, access, procedure
#   planned_parenthood, pro-life, pro-choice, reproductive_rights, roe_v._wade, anti-abortion
# Topic 45:
#   tribe, pipeline, hospital, agency, made, ihs, told, health, said., part
#   north_dakota, native_american, native_americans, dakota_access_pipeline, south_dakota, standing_rock
# Topic 46:
#   didn, told, time, wanted, knew, thought, asked, night, day, felt
#   told_me, felt_like, next_day, talked_about, no_idea, looked_like
# Topic 47:
#   post, brooklyn, city, manhattan, mayor, train, told, sources, nypd, cuomo
#   new_york, new_york_city, new_jersey, de_blasio, new_yorkers, long_island
# Topic 48:
#   moment, sense, world, man, power, end, makes, long, moments, turn
#   many_ways, no_doubt, no_matter_how, ever_since, apart_from, penchant_for
# Topic 49:
#   president, voice, accused, hold, members, breaking, watch, people, refused, lift
#   get_worse, few_breaks, professional_opinion_about, stealing_police_cars, sue_finley_was, hired_at_jpl
# Topic 50:
#   year, time, end, month, long, early, january, years, november, past
#   two_years, next_year, last_month, less_than, two_months, this_week
# Topic 51:
#   apple, google, phone, app, devices, iphone, device, company, microsoft, data
#   your_phone, iphone_7, apple_watch, pokémon_go, san_bernardino, tech_companies
# Topic 52:
#   french, france, paris, de, macron, nice, la, people, brian, le
#   le_pen, national_front, marine_le_pen, de_la, his_wife, emmanuel_macron
# Topic 53:
#   report, reports, reported, found, released, time, notes, information, published, made
#   last_month, earlier_this_month, state_department, last_october, crimes_against, an_attempt
# Topic 54:
#   church, god, christian, faith, people, religious, christians, religion, pope, life
#   pope_francis, catholic_church, told_me, lopez_:, jesus_christ, mother_teresa
# Topic 55:
#   fed, market, economy, year, investors, expected, u.s., inflation, growth, bank
#   s_&_p, federal_reserve, last_month, on_wednesday, new_york, wall_street
# Topic 56:
#   trump, president, comey, russia, flynn, investigation, campaign, fbi, officials, committee
#   white_house, justice_department, senate_intelligence_committee, president_donald_trump, james_comey, house_intelligence_committee
# Topic 57:
#   people, protesters, protest, march, group, protests, violence, rally, supporters, activists
#   black_lives_matter, shut_down, protest_against, took_place, anti-trump, protests_against
# Topic 58:
#   prison, case, trial, judge, prosecutors, court, convicted, crime, jail, sentenced
#   charged_with, pleaded_guilty, found_guilty, behind_bars, district_attorney, three_years
# Topic 59:
#   britain, british, eu, london, uk, leave, brexit, remain, government, referendum
#   european_union, prime_minister, united_kingdom, theresa_may, northern_ireland, conservative_party
# Topic 60:
#   students, school, university, education, schools, student, college, campus, teachers, class
#   public_schools, charter_schools, education_department, common_core, college_students, safe_spaces
# Topic 61:
#   find, answer, reader, note, read, time, here., don, answers, ve
#   this_week, scroll_down_for, another_reader, ve_been, atlantic_daily, last_week
# Topic 62:
#   patients, drug, drugs, doctors, health, hospital, treatment, medical, doctor, patient
#   diagnosed_with, mental_illness, drug_administration, medical_center, medical_care, medical_marijuana
# Topic 63:
#   cases, zika, health, virus, people, spread, disease, risk, infected, world
#   zika_virus, pregnant_women, for_disease_control, united_states, health_organization, puerto_rico
# Topic 64:
#   people, killed, fire, victims, injured, attack, dead, hospital, died, update
#   death_toll, associated_press, being_treated, critical_condition, saturday_night, our_thoughts
# Topic 65:
#   animals, species, farmers, animal, fish, farm, world, wild, human, humans
#   years_ago, endangered_species, wildlife_service, north_america, looks_like, at_2016_highlights
# Topic 66:
#   police, man, arrested, told, authorities, found, woman, suspect, incident, victim
#   charged_with, being_held, his_wife, police_department, taken_into_custody, medical_examiner
# Topic 67:
#   facebook, internet, online, people, users, content, post, site, company, news
#   facebook_page, social_network, buzzfeed_news, mark_zuckerberg, news_feed, told_buzzfeed_news
# Topic 68:
#   death, died, cuba, king, life, family, man, father, years, great
#   his_wife, fidel_castro, world_war_ii, passed_away, muhammad_ali, united_states
# Topic 69:
#   people, world, live, africa, told, country, time, nigeria, ghana, work
#   south_africa, boko_haram, south_african, ivory_coast, west_africa, buzzfeed_news
# Topic 70:
#   statement, friday, said., thursday, monday, tuesday, told, saturday, announced, sunday
#   told_cnn, last_week, on_wednesday, this_week, told_reporters, associated_press
# Topic 71:
#   time, work, hours, week, home, days, working, leave, staff, day
#   two_weeks, six_months, how_much, even_though, five_years, seven_days
# Topic 72:
#   government, country, president, brazil, venezuela, opposition, power, state, corruption, office
#   latin_america, united_nations, this_week, use_force, diplomatic_action_against_pyongyang, stop_north_korea
# Topic 73:
#   gypsy, marriage, couple, relationship, told, married, time, wife, people, life
#   her_husband, dee_dee, his_wife, her_mother, told_me, my_son
# Topic 74:
#   people, time, make, campaign, president, nixon, lewis, public, made, man
#   donald_trump, hillary_clinton, tax_returns, his_tax_returns, richard_nixon, washington_post
# Topic 75:
#   reuters, u.s., minimum, delays, video, mobile, exchanges, news, tuesday, friday
#   on_wednesday, 15_minutes, personal_finance, world_news, business_news, headline_news
# Topic 76:
#   case, filed, lawsuit, investigation, lawyer, office, attorney, department, allegations, claims
#   justice_department, federal_court, investigation_into, lawsuit_against, on_behalf, court_documents
# Topic 77:
#   day, event, year, events, time, weekend, attend, held, holiday, annual
#   this_week, take_place, last_night, next_week, at_6_a.m., took_place
# Topic 78:
#   show, hollywood, moore, star, award, won, fan, year, video, time
#   los_angeles, killed_off, by_jason_h, fan_reactions, ``_justin_chang, his_favorite_part
# Topic 79:
#   iran, iranian, stewart, qatar, saudi, tehran, sanctions, washington, failure, yemen
#   saudi_arabia, attack_against, this_week, with_nato_allies, an_earlier_trip, still_rattled_by
# Topic 80:
#   twitter, tweet, tweets, tweeted, people, account, milo, abuse, company, platform
#   alt-right, twitter_account, &_amp, https_:, can_follow_him, breitbart_tech
# Topic 81:
#   smith, jones, john, lee, michael, david, brown, martin, james, thomas
#   &_amp, his_wife, st._louis, ended_up, las_vegas, 30_years
# Topic 82:
#   speech, pence, country, people, advertisement, cnn, crowd, asked, great, tonight
#   https_:, donald_trump, &_amp, last_night, follow_pam_key, mike_pence
# Topic 83:
#   time, miller, city, people, march, group, utah, work, day, taking
#   salt_lake_city, other_side, ciudad_juárez, three_years_ago, ve_been, focused_on
# Topic 84:
#   show, network, fox, tv, kelly, shows, television, nbc, host, media
#   fox_news, megyn_kelly, mr._ailes, fox_news_channel, last_week, co-host
# Topic 85:
#   attack, attacks, terrorism, isis, security, terrorists, killed, people, pakistan, terrorist
#   islamic_state, carried_out, terrorist_attacks, terrorist_attack, terror_attacks, al-qaeda
# Topic 86:
#   party, political, politics, conservative, election, power, voters, country, issues, national
#   donald_trump, american_politics, status_quo, anti-establishment, right-wing, working-class
# Topic 87:
#   muslims, muslim, islam, religion, people, islamic, act, mosque, group, country
#   radical_islam, twin_falls, muslim_brotherhood, middle_east, hate_crimes, anti-muslim
# Topic 88:
#   clinton, fbi, emails, email, state, secretary, information, comey, investigation, government
#   state_department, hillary_clinton, clinton_foundation, justice_department, private_email_server, e-mails
# Topic 89:
#   energy, oil, water, epa, climate, environmental, lead, coal, gas, power
#   environmental_protection_agency, paris_agreement, drinking_water, clean_power_plan, fossil_fuels, air_pollution
# Topic 90:
#   people, feel, love, life, friends, fear, lives, person, hope, words
#   my_wife, my_heart, feel_like, how_much, loved_ones, family_members
# Topic 91:
#   people, lot, things, time, work, kind, make, good, thing, job
#   talk_about, little_bit, feel_like, talking_about, thinking_about, talked_about
# Topic 92:
#   role, time, play, part, made, people, wanted, wilson, good, didn
#   even_though, ve_been, los_angeles, no_matter, status_quo, figure_out_how
# Topic 93:
#   city, people, local, cities, community, residents, town, area, neighborhood, live
#   san_francisco, los_angeles, puerto_rico, city_council, grew_up, new_orleans
# Topic 94:
#   guy, good, thing, man, things, kind, real, bad, joke, love
#   gon_na, looks_like, better_than, talking_about, i_guess, pretty_much
# Topic 95:
#   black, white, people, race, racist, racism, color, diversity, history, americans
#   african-american, african-americans, black_lives_matter, black_men, white_men, black_man
# Topic 96:
#   law, rules, policy, government, rule, laws, act, federal, order, legal
#   comply_with, federal_law, would_require, into_effect, federal_agencies, title_ix
# Topic 97:
#   number, year, data, average, numbers, compared, rate, population, increased, americans
#   more_likely, less_than, higher_than, recent_years, more_than_half, 40_percent
# Topic 98:
#   isis, iraq, city, mosul, syria, fighting, group, forces, civilians, militants
#   islamic_state, iraqi_forces, security_forces, backed_by, isis_fighters, iraqi_government
# Topic 99:
#   american, people, history, freedom, culture, political, power, world, society, today
#   civil_war, our_nation, human_beings, for_instance, associated_with, united_states
# Topic 100:
#   people, dog, dogs, time, didn, man, cooper, cat, don, wanted
#   ve_been, ended_up, last_week, sex_workers, ve_seen, told_me
# Topic 101:
#   money, bank, pay, banks, financial, cash, paid, million, debt, business
#   wall_street, wells_fargo, goldman_sachs, financial_crisis, deutsche_bank, how_much
# Topic 102:
#   ms., campaign, president, added, mr, washington, called, american, friday, made
#   mr._trump, mrs._clinton, mr._obama, united_states, donald_j._trump, an_interview
# Topic 103:
#   trump, campaign, president, election, supporters, presidency, donald, trump., republican, comments
#   donald_trump, president-elect, white_house, president-elect_donald_trump, trump_tower, hillary_clinton
# Topic 104:
#   don, people, doesn, ll, didn, ve, lot, things, good, isn
#   re_going, ve_been, ve_got, talk_about, m_going, talking_about
# Topic 105:
#   film, movie, show, character, series, story, movies, films, characters, hollywood
#   star_wars, star_trek, wonder_woman, tv_series, real-life, tv_shows
# Topic 106:
#   president, organization, interest, business, conflicts, hotel, company, office, table, family
#   ivanka_trump, president-elect, united_states, business_interests, new_york_times, phone_call
# Topic 107:
#   u.s., world, american, countries, policy, international, global, allies, nato, leaders
#   united_states, middle_east, state_department, other_countries, cold_war, president_obama
# Topic 108:
#   game, team, season, players, play, games, nfl, league, win, teams
#   super_bowl, organized_team_activities, lindsey_thiry_discuss, rams_made_during_offseason, los_angeles, san_diego
# Topic 109:
#   music, song, album, band, songs, prince, love, singer, track, rock
#   hip-hop, day_archive_here, pre-notes_archive_here, &_amp, kanye_west, david_bowie
# Topic 110:
#   information, government, security, russia, intelligence, cia, data, documents, officials, hacking
#   russian_government, intelligence_agencies, democratic_national_committee, intelligence_officials, national_security_agency, national_intelligence
# Topic 111:
#   question, make, fact, point, problem, case, simply, reason, clear, means
#   other_words, for_instance, more_likely, other_hand, how_much, pointed_out
# Topic 112:
#   art, work, museum, image, images, photo, artist, world, history, stone
#   new_york, inspired_by, most_famous, national_museum, contemporary_art, looks_like
# Topic 113:
#   company, employees, companies, ceo, business, firm, work, investors, executives, executive
#   silicon_valley, chief_executive, san_francisco, co-founder, former_employees, less_than
# Topic 114:
#   earth, space, nasa, planet, moon, time, scientists, mars, mission, life
#   solar_system, years_ago, black_holes, international_space_station, black_hole, gravitational_waves
# Topic 115:
#   europe, germany, german, migrants, european, italy, country, berlin, sweden, eu
#   european_union, german_chancellor_angela_merkel, across_europe, migrant_crisis, prime_minister, angela_merkel
# Topic 116:
#   book, books, read, story, writing, life, wrote, write, author, time
#   new_york_times, new_yorker, new_york, obsessed_with, harry_potter, nobel_prize
# Topic 117:
#   election, vote, voters, voting, votes, voted, elections, won, campaign, people
#   election_day, donald_trump, hillary_clinton, election_results, november_8, last_week
# Topic 118:
#   court, case, decision, law, judge, order, ruling, constitution, legal, judges
#   justice_department, united_states, u.s._supreme_court, federal_judge, justice_scalia, judge_gorsuch
# Topic 119:
#   president, obama, administration, office, washington, bush, presidency, presidents, american, americans
#   white_house, president_obama, president_barack_obama, barack_obama, united_states, president_donald_trump
# Topic 120:
#   workers, work, job, employees, jobs, working, pay, union, labor, people
#   an_hour, blue_apron, less_than, full-time, labor_department, part-time
# Topic 121:
#   study, research, researchers, university, found, science, people, scientists, studies, results
#   more_likely, associated_with, researchers_found, lead_author, study_found, co-author
# Topic 122:
#   sessions, secretary, nomination, senate, pick, nominee, confirmed, department, tillerson, experience
#   president-elect, president-elect_donald_trump, transition_team, jeff_sessions, confirmation_hearings, rex_tillerson
# Topic 123:
#   police, officers, shot, officer, shooting, killed, gun, chicago, city, dallas
#   police_officers, police_officer, police_department, baton_rouge, police_chief, fatally_shot
# Topic 124:
#   asked, letter, wrote, comment, told, question, said., response, questions, request
#   buzzfeed_news, told_buzzfeed_news, an_email, an_interview, questions_about, reached_out
# Topic 125:
#   video, videos, shows, footage, showed, camera, people, posted, case, released
#   video_footage, san_francisco, new_york_city, shortly_after, two_years, young_man
# Topic 126:
#   military, war, afghanistan, army, u.s., soldiers, pentagon, american, defense, troops
#   u.s._military, air_force, united_states, service_members, marine_corps, armed_forces
# Topic 127:
#   williams, jackson, things, davis, rose, time, don, people, part, system
#   told_me, how_much, worry_about, looks_like, talking_about, two_years

# %%
def save_model(model, tag, directory=MODEL_DIRECTORY):
    path = os.path.join(directory, "model-%s.pkl" % tag)
    print("Saving topic model to %s." % path)
    model.save(path)

def load_model(tag, directory=MODEL_DIRECTORY):
    path = os.path.join(directory, "model-%s.pkl" % tag)
    print("Loading topic model from %s." % path)
    model = LdaMallet.load(path)
    return model

tag = "%d-%d-%d-%d-%d-%d-%d" % (
    builder.ndocs, 
    builder.vocabulary_size, 
    builder.bigram_min_count, 
    builder.bigram_threshold,
    builder.trigram_min_count, 
    builder.trigram_threshold,
    num_topics
)
save_model(model, tag, directory=MODEL_DIRECTORY)
#show_topic_model(model, builder.dictionary, use_phrasers=True)
# Out:
# Saving topic model to ./model/all-the-news/model-128305-50000-5-10-5-10-128.pkl.

# %%
loaded_model = load_model(tag, directory=MODEL_DIRECTORY)
show_topic_model(loaded_model, builder.dictionary, use_phrasers=True)
# Out:
# Loading topic model from ./model/all-the-news/model-128305-50000-5-10-5-10-128.pkl.
# Topic 0:
#   state, states, california, texas, governor, law, virginia, florida, colorado, bill
#   north_carolina, west_virginia, south_carolina, executive_director, new_mexico, rhode_island
# Topic 1:
#   china, chinese, japan, beijing, country, u.s., japanese, kim, taiwan, pyongyang
#   north_korea, south_korea, united_states, hong_kong, north_korean, south_china_sea
# Topic 2:
#   wearing, fashion, wear, dress, hair, wore, clothes, style, shoes, model
#   post_shared_by, t-shirt, t-shirts, photo_posted_by, inspired_by, her_husband
# Topic 3:
#   israel, jewish, israeli, jews, time, palestinians, jerusalem, netanyahu, palestinian, people
#   west_bank, united_states, anti-semitism, two-state_solution, tel_aviv, middle_east
# Topic 4:
#   company, sales, products, customers, market, business, consumers, companies, amazon, price
#   less_than, whole_foods, wal-mart, chief_executive, two_years, e-commerce
# Topic 5:
#   trump, support, vote, republican, president, nominee, romney, party, told, mccain
#   donald_trump, hillary_clinton, republican_nominee, mitt_romney, may_5, paul_ryan
# Topic 6:
#   johnson, green, open, day, made, time, good, walker, shot, play
#   follow_warner_todd_huston, author_at_igcolonel, warnerthuston_or_email, this_week, golf_course, pga_tour
# Topic 7:
#   people, water, storm, snow, officials, fire, expected, area, rain, residents
#   their_homes, national_weather_service, hurricane_matthew, south_carolina, east_coast, all_rights_reserved
# Topic 8:
#   turkey, government, turkish, country, egypt, erdogan, istanbul, military, officials, ankara
#   coup_attempt, turkish_government, mr._erdogan, prime_minister, united_states, middle_east
# Topic 9:
#   people, transgender, year, bathroom, gender, trans, face, time, person, call
#   transgender_people, trans_women, trans_people, even_though, how_much, north_carolina
# Topic 10:
#   team, won, players, win, athletes, game, match, sport, games, sports
#   world_cup, rio_de_janeiro, premier_league, olympic_games, manchester_united, international_olympic_committee
# Topic 11:
#   refugees, people, country, canada, australia, countries, camp, canadian, refugee, government
#   united_states, syrian_refugees, united_nations, south_sudan, last_week, other_countries
# Topic 12:
#   media, news, story, times, article, press, journalists, reporters, reporter, stories
#   new_york_times, washington_post, huffington_post, news_organizations, news_outlets, media_outlets
# Topic 13:
#   technology, system, future, world, make, create, work, human, things, process
#   focused_on, rely_on, interact_with, for_instance, co-founder, focusing_on
# Topic 14:
#   republicans, bill, house, democrats, senate, republican, ryan, vote, members, legislation
#   white_house, capitol_hill, house_speaker_paul_ryan, house_republicans, paul_ryan, this_week
# Topic 15:
#   game, team, season, yankees, mets, baseball, hit, series, play, field
#   last_season, red_sox, major_league_baseball, home_runs, right-hander, at-bats
# Topic 16:
#   voters, democrats, poll, support, republicans, polls, win, won, clinton, race
#   hillary_clinton, donald_trump, 40_percent, exit_polls, mitt_romney, north_carolina
# Topic 17:
#   women, men, woman, female, sex, girls, male, man, gender, girl
#   young_men, young_girls, even_though, gender_equality, young_woman, equal_pay
# Topic 18:
#   people, obamacare, health, insurance, coverage, law, plans, repeal, states, americans
#   affordable_care_act, insurance_companies, tax_credits, medicaid_expansion, health-care, congressional_budget_office
# Topic 19:
#   company, deal, shares, billion, companies, business, investors, stock, sources, revenue
#   chief_executive, on_wednesday, per_share, people_familiar, time_warner, wall_street
# Topic 20:
#   meeting, deal, agreement, meet, talks, agreed, leaders, met, officials, issues
#   on_wednesday, last_week, this_week, both_sides, told_reporters, next_week
# Topic 21:
#   day, time, body, night, sleep, head, hands, hand, face, small
#   an_hour, your_body, filled_with, two_hours, feel_like, 20_minutes
# Topic 22:
#   advertisement, breitbart, bannon, added, news, stated, media, continued, twitter, conservative
#   breitbart_news, follow_him_on, told_breitbart_news, breitbart_news_daily, steve_bannon, on_siriusxm_patriot
# Topic 23:
#   group, members, organization, groups, foundation, money, campaign, support, including, organizations
#   executive_director, on_behalf, last_month, funded_by, focused_on, raise_money
# Topic 24:
#   russia, syria, russian, putin, moscow, assad, aleppo, syrian, ukraine, rebels
#   united_states, russian_president_vladimir, syrian_government, united_nations, vladimir_putin, civil_war
# Topic 25:
#   plane, flight, airport, passengers, aircraft, air, travel, flying, airline, fly
#   air_force, coast_guard, international_airport, crew_members, flight_attendant, american_airlines
# Topic 26:
#   left, conservatives, conservative, political, liberal, isn, liberals, americans, american, fact
#   related_:, donald_trump, national_review, share_article_on_facebooksharetweet, national_review., left-wing
# Topic 27:
#   jobs, economy, american, trade, u.s., tax, companies, business, country, taxes
#   united_states, economic_growth, american_workers, other_countries, trade_deals, tax_cuts
# Topic 28:
#   immigration, mexico, u.s., immigrants, border, wall, country, mexican, texas, ice
#   united_states, breitbart_texas, illegal_immigrants, undocumented_immigrants, illegal_immigration, illegal_aliens
# Topic 29:
#   uber, car, cars, tesla, drivers, driver, company, vehicles, driving, ford
#   self-driving_cars, model_3, san_francisco, self-driving, general_motors, autonomous_vehicles
# Topic 30:
#   india, people, world, indian, google, make, time, things, light, made
#   new_delhi, united_states, how_much, less_than, questions_about, years_ago
# Topic 31:
#   program, government, funding, money, programs, cost, system, public, federal, support
#   focused_on, food_stamps, long-term, how_much, rely_on, low-income
# Topic 32:
#   claims, claim, made, comments, claimed, fact, public, called, statement, accused
#   last_week, conspiracy_theories, no_evidence, press_conference, an_apology, pointed_out
# Topic 33:
#   gun, guns, people, reach, firearms, radio, advertisement, weapons, nra, twitter
#   second_amendment, awr_hawkins, follow_him_on, political_analyst, breitbart_news, directly_at_awrhawkins
# Topic 34:
#   building, home, house, hotel, property, space, apartment, homes, room, buildings
#   square_feet, owned_by, view_slideshow, his_wife, las_vegas, co-op
# Topic 35:
#   cruz, rubio, campaign, delegates, win, iowa, kasich, candidate, convention, race
#   ted_cruz, new_hampshire, donald_trump, south_carolina, marco_rubio, john_kasich
# Topic 36:
#   rape, people, time, victims, dunn, raped, told, mitchell, country, women
#   sexual_violence, new_orleans, ve_been, united_states, new_york, violence_against
# Topic 37:
#   free, point, serve, meant, work, type, seeking, plans, providing, closing
#   wayback_machine, dig_into, first_stop, be_made_available, internet_archive, path_back
# Topic 38:
#   children, family, parents, mother, kids, child, father, son, home, life
#   her_mother, her_husband, her_daughter, my_father, grew_up, his_wife
# Topic 39:
#   clinton, campaign, sanders, hillary, debate, candidate, democrats, supporters, candidates, democratic
#   hillary_clinton, bernie_sanders, donald_trump, bill_clinton, former_secretary, her_husband
# Topic 40:
#   water, land, park, town, island, river, area, beach, village, road
#   national_park, national_park_service, surrounded_by, filled_with, national_parks, national_monument
# Topic 41:
#   gay, people, orlando, club, mateen, group, lgbt, time, support, make
#   lgbt_people, lgbt_community, sexual_orientation, omar_mateen, same-sex_marriage, marriage_equality
# Topic 42:
#   food, eat, restaurant, eating, make, sugar, made, coffee, restaurants, drink
#   filled_with, peanut_butter, burger_king, fried_chicken, olive_oil, taco_bell
# Topic 43:
#   call, calls, time, called, day, anderson, part, give, people, home
#   more_likely, phone_calls, even_though, phone_call, anything_else, recent_years
# Topic 44:
#   women, abortion, life, woman, health, abortions, pregnancy, baby, access, procedure
#   planned_parenthood, pro-life, pro-choice, reproductive_rights, roe_v._wade, anti-abortion
# Topic 45:
#   tribe, pipeline, hospital, agency, made, ihs, told, health, said., part
#   north_dakota, native_american, native_americans, dakota_access_pipeline, south_dakota, standing_rock
# Topic 46:
#   didn, told, time, wanted, knew, thought, asked, night, day, felt
#   told_me, felt_like, next_day, talked_about, no_idea, looked_like
# Topic 47:
#   post, brooklyn, city, manhattan, mayor, train, told, sources, nypd, cuomo
#   new_york, new_york_city, new_jersey, de_blasio, new_yorkers, long_island
# Topic 48:
#   moment, sense, world, man, power, end, makes, long, moments, turn
#   many_ways, no_doubt, no_matter_how, ever_since, apart_from, penchant_for
# Topic 49:
#   president, voice, accused, hold, members, breaking, watch, people, refused, lift
#   get_worse, few_breaks, professional_opinion_about, stealing_police_cars, sue_finley_was, hired_at_jpl
# Topic 50:
#   year, time, end, month, long, early, january, years, november, past
#   two_years, next_year, last_month, less_than, two_months, this_week
# Topic 51:
#   apple, google, phone, app, devices, iphone, device, company, microsoft, data
#   your_phone, iphone_7, apple_watch, pokémon_go, san_bernardino, tech_companies
# Topic 52:
#   french, france, paris, de, macron, nice, la, people, brian, le
#   le_pen, national_front, marine_le_pen, de_la, his_wife, emmanuel_macron
# Topic 53:
#   report, reports, reported, found, released, time, notes, information, published, made
#   last_month, earlier_this_month, state_department, last_october, crimes_against, an_attempt
# Topic 54:
#   church, god, christian, faith, people, religious, christians, religion, pope, life
#   pope_francis, catholic_church, told_me, lopez_:, jesus_christ, mother_teresa
# Topic 55:
#   fed, market, economy, year, investors, expected, u.s., inflation, growth, bank
#   s_&_p, federal_reserve, last_month, on_wednesday, new_york, wall_street
# Topic 56:
#   trump, president, comey, russia, flynn, investigation, campaign, fbi, officials, committee
#   white_house, justice_department, senate_intelligence_committee, president_donald_trump, james_comey, house_intelligence_committee
# Topic 57:
#   people, protesters, protest, march, group, protests, violence, rally, supporters, activists
#   black_lives_matter, shut_down, protest_against, took_place, anti-trump, protests_against
# Topic 58:
#   prison, case, trial, judge, prosecutors, court, convicted, crime, jail, sentenced
#   charged_with, pleaded_guilty, found_guilty, behind_bars, district_attorney, three_years
# Topic 59:
#   britain, british, eu, london, uk, leave, brexit, remain, government, referendum
#   european_union, prime_minister, united_kingdom, theresa_may, northern_ireland, conservative_party
# Topic 60:
#   students, school, university, education, schools, student, college, campus, teachers, class
#   public_schools, charter_schools, education_department, common_core, college_students, safe_spaces
# Topic 61:
#   find, answer, reader, note, read, time, here., don, answers, ve
#   this_week, scroll_down_for, another_reader, ve_been, atlantic_daily, last_week
# Topic 62:
#   patients, drug, drugs, doctors, health, hospital, treatment, medical, doctor, patient
#   diagnosed_with, mental_illness, drug_administration, medical_center, medical_care, medical_marijuana
# Topic 63:
#   cases, zika, health, virus, people, spread, disease, risk, infected, world
#   zika_virus, pregnant_women, for_disease_control, united_states, health_organization, puerto_rico
# Topic 64:
#   people, killed, fire, victims, injured, attack, dead, hospital, died, update
#   death_toll, associated_press, being_treated, critical_condition, saturday_night, our_thoughts
# Topic 65:
#   animals, species, farmers, animal, fish, farm, world, wild, human, humans
#   years_ago, endangered_species, wildlife_service, north_america, looks_like, at_2016_highlights
# Topic 66:
#   police, man, arrested, told, authorities, found, woman, suspect, incident, victim
#   charged_with, being_held, his_wife, police_department, taken_into_custody, medical_examiner
# Topic 67:
#   facebook, internet, online, people, users, content, post, site, company, news
#   facebook_page, social_network, buzzfeed_news, mark_zuckerberg, news_feed, told_buzzfeed_news
# Topic 68:
#   death, died, cuba, king, life, family, man, father, years, great
#   his_wife, fidel_castro, world_war_ii, passed_away, muhammad_ali, united_states
# Topic 69:
#   people, world, live, africa, told, country, time, nigeria, ghana, work
#   south_africa, boko_haram, south_african, ivory_coast, west_africa, buzzfeed_news
# Topic 70:
#   statement, friday, said., thursday, monday, tuesday, told, saturday, announced, sunday
#   told_cnn, last_week, on_wednesday, this_week, told_reporters, associated_press
# Topic 71:
#   time, work, hours, week, home, days, working, leave, staff, day
#   two_weeks, six_months, how_much, even_though, five_years, seven_days
# Topic 72:
#   government, country, president, brazil, venezuela, opposition, power, state, corruption, office
#   latin_america, united_nations, this_week, use_force, diplomatic_action_against_pyongyang, stop_north_korea
# Topic 73:
#   gypsy, marriage, couple, relationship, told, married, time, wife, people, life
#   her_husband, dee_dee, his_wife, her_mother, told_me, my_son
# Topic 74:
#   people, time, make, campaign, president, nixon, lewis, public, made, man
#   donald_trump, hillary_clinton, tax_returns, his_tax_returns, richard_nixon, washington_post
# Topic 75:
#   reuters, u.s., minimum, delays, video, mobile, exchanges, news, tuesday, friday
#   on_wednesday, 15_minutes, personal_finance, world_news, business_news, headline_news
# Topic 76:
#   case, filed, lawsuit, investigation, lawyer, office, attorney, department, allegations, claims
#   justice_department, federal_court, investigation_into, lawsuit_against, on_behalf, court_documents
# Topic 77:
#   day, event, year, events, time, weekend, attend, held, holiday, annual
#   this_week, take_place, last_night, next_week, at_6_a.m., took_place
# Topic 78:
#   show, hollywood, moore, star, award, won, fan, year, video, time
#   los_angeles, killed_off, by_jason_h, fan_reactions, ``_justin_chang, his_favorite_part
# Topic 79:
#   iran, iranian, stewart, qatar, saudi, tehran, sanctions, washington, failure, yemen
#   saudi_arabia, attack_against, this_week, with_nato_allies, an_earlier_trip, still_rattled_by
# Topic 80:
#   twitter, tweet, tweets, tweeted, people, account, milo, abuse, company, platform
#   alt-right, twitter_account, &_amp, https_:, can_follow_him, breitbart_tech
# Topic 81:
#   smith, jones, john, lee, michael, david, brown, martin, james, thomas
#   &_amp, his_wife, st._louis, ended_up, las_vegas, 30_years
# Topic 82:
#   speech, pence, country, people, advertisement, cnn, crowd, asked, great, tonight
#   https_:, donald_trump, &_amp, last_night, follow_pam_key, mike_pence
# Topic 83:
#   time, miller, city, people, march, group, utah, work, day, taking
#   salt_lake_city, other_side, ciudad_juárez, three_years_ago, ve_been, focused_on
# Topic 84:
#   show, network, fox, tv, kelly, shows, television, nbc, host, media
#   fox_news, megyn_kelly, mr._ailes, fox_news_channel, last_week, co-host
# Topic 85:
#   attack, attacks, terrorism, isis, security, terrorists, killed, people, pakistan, terrorist
#   islamic_state, carried_out, terrorist_attacks, terrorist_attack, terror_attacks, al-qaeda
# Topic 86:
#   party, political, politics, conservative, election, power, voters, country, issues, national
#   donald_trump, american_politics, status_quo, anti-establishment, right-wing, working-class
# Topic 87:
#   muslims, muslim, islam, religion, people, islamic, act, mosque, group, country
#   radical_islam, twin_falls, muslim_brotherhood, middle_east, hate_crimes, anti-muslim
# Topic 88:
#   clinton, fbi, emails, email, state, secretary, information, comey, investigation, government
#   state_department, hillary_clinton, clinton_foundation, justice_department, private_email_server, e-mails
# Topic 89:
#   energy, oil, water, epa, climate, environmental, lead, coal, gas, power
#   environmental_protection_agency, paris_agreement, drinking_water, clean_power_plan, fossil_fuels, air_pollution
# Topic 90:
#   people, feel, love, life, friends, fear, lives, person, hope, words
#   my_wife, my_heart, feel_like, how_much, loved_ones, family_members
# Topic 91:
#   people, lot, things, time, work, kind, make, good, thing, job
#   talk_about, little_bit, feel_like, talking_about, thinking_about, talked_about
# Topic 92:
#   role, time, play, part, made, people, wanted, wilson, good, didn
#   even_though, ve_been, los_angeles, no_matter, status_quo, figure_out_how
# Topic 93:
#   city, people, local, cities, community, residents, town, area, neighborhood, live
#   san_francisco, los_angeles, puerto_rico, city_council, grew_up, new_orleans
# Topic 94:
#   guy, good, thing, man, things, kind, real, bad, joke, love
#   gon_na, looks_like, better_than, talking_about, i_guess, pretty_much
# Topic 95:
#   black, white, people, race, racist, racism, color, diversity, history, americans
#   african-american, african-americans, black_lives_matter, black_men, white_men, black_man
# Topic 96:
#   law, rules, policy, government, rule, laws, act, federal, order, legal
#   comply_with, federal_law, would_require, into_effect, federal_agencies, title_ix
# Topic 97:
#   number, year, data, average, numbers, compared, rate, population, increased, americans
#   more_likely, less_than, higher_than, recent_years, more_than_half, 40_percent
# Topic 98:
#   isis, iraq, city, mosul, syria, fighting, group, forces, civilians, militants
#   islamic_state, iraqi_forces, security_forces, backed_by, isis_fighters, iraqi_government
# Topic 99:
#   american, people, history, freedom, culture, political, power, world, society, today
#   civil_war, our_nation, human_beings, for_instance, associated_with, united_states
# Topic 100:
#   people, dog, dogs, time, didn, man, cooper, cat, don, wanted
#   ve_been, ended_up, last_week, sex_workers, ve_seen, told_me
# Topic 101:
#   money, bank, pay, banks, financial, cash, paid, million, debt, business
#   wall_street, wells_fargo, goldman_sachs, financial_crisis, deutsche_bank, how_much
# Topic 102:
#   ms., campaign, president, added, mr, washington, called, american, friday, made
#   mr._trump, mrs._clinton, mr._obama, united_states, donald_j._trump, an_interview
# Topic 103:
#   trump, campaign, president, election, supporters, presidency, donald, trump., republican, comments
#   donald_trump, president-elect, white_house, president-elect_donald_trump, trump_tower, hillary_clinton
# Topic 104:
#   don, people, doesn, ll, didn, ve, lot, things, good, isn
#   re_going, ve_been, ve_got, talk_about, m_going, talking_about
# Topic 105:
#   film, movie, show, character, series, story, movies, films, characters, hollywood
#   star_wars, star_trek, wonder_woman, tv_series, real-life, tv_shows
# Topic 106:
#   president, organization, interest, business, conflicts, hotel, company, office, table, family
#   ivanka_trump, president-elect, united_states, business_interests, new_york_times, phone_call
# Topic 107:
#   u.s., world, american, countries, policy, international, global, allies, nato, leaders
#   united_states, middle_east, state_department, other_countries, cold_war, president_obama
# Topic 108:
#   game, team, season, players, play, games, nfl, league, win, teams
#   super_bowl, organized_team_activities, lindsey_thiry_discuss, rams_made_during_offseason, los_angeles, san_diego
# Topic 109:
#   music, song, album, band, songs, prince, love, singer, track, rock
#   hip-hop, day_archive_here, pre-notes_archive_here, &_amp, kanye_west, david_bowie
# Topic 110:
#   information, government, security, russia, intelligence, cia, data, documents, officials, hacking
#   russian_government, intelligence_agencies, democratic_national_committee, intelligence_officials, national_security_agency, national_intelligence
# Topic 111:
#   question, make, fact, point, problem, case, simply, reason, clear, means
#   other_words, for_instance, more_likely, other_hand, how_much, pointed_out
# Topic 112:
#   art, work, museum, image, images, photo, artist, world, history, stone
#   new_york, inspired_by, most_famous, national_museum, contemporary_art, looks_like
# Topic 113:
#   company, employees, companies, ceo, business, firm, work, investors, executives, executive
#   silicon_valley, chief_executive, san_francisco, co-founder, former_employees, less_than
# Topic 114:
#   earth, space, nasa, planet, moon, time, scientists, mars, mission, life
#   solar_system, years_ago, black_holes, international_space_station, black_hole, gravitational_waves
# Topic 115:
#   europe, germany, german, migrants, european, italy, country, berlin, sweden, eu
#   european_union, german_chancellor_angela_merkel, across_europe, migrant_crisis, prime_minister, angela_merkel
# Topic 116:
#   book, books, read, story, writing, life, wrote, write, author, time
#   new_york_times, new_yorker, new_york, obsessed_with, harry_potter, nobel_prize
# Topic 117:
#   election, vote, voters, voting, votes, voted, elections, won, campaign, people
#   election_day, donald_trump, hillary_clinton, election_results, november_8, last_week
# Topic 118:
#   court, case, decision, law, judge, order, ruling, constitution, legal, judges
#   justice_department, united_states, u.s._supreme_court, federal_judge, justice_scalia, judge_gorsuch
# Topic 119:
#   president, obama, administration, office, washington, bush, presidency, presidents, american, americans
#   white_house, president_obama, president_barack_obama, barack_obama, united_states, president_donald_trump
# Topic 120:
#   workers, work, job, employees, jobs, working, pay, union, labor, people
#   an_hour, blue_apron, less_than, full-time, labor_department, part-time
# Topic 121:
#   study, research, researchers, university, found, science, people, scientists, studies, results
#   more_likely, associated_with, researchers_found, lead_author, study_found, co-author
# Topic 122:
#   sessions, secretary, nomination, senate, pick, nominee, confirmed, department, tillerson, experience
#   president-elect, president-elect_donald_trump, transition_team, jeff_sessions, confirmation_hearings, rex_tillerson
# Topic 123:
#   police, officers, shot, officer, shooting, killed, gun, chicago, city, dallas
#   police_officers, police_officer, police_department, baton_rouge, police_chief, fatally_shot
# Topic 124:
#   asked, letter, wrote, comment, told, question, said., response, questions, request
#   buzzfeed_news, told_buzzfeed_news, an_email, an_interview, questions_about, reached_out
# Topic 125:
#   video, videos, shows, footage, showed, camera, people, posted, case, released
#   video_footage, san_francisco, new_york_city, shortly_after, two_years, young_man
# Topic 126:
#   military, war, afghanistan, army, u.s., soldiers, pentagon, american, defense, troops
#   u.s._military, air_force, united_states, service_members, marine_corps, armed_forces
# Topic 127:
#   williams, jackson, things, davis, rose, time, don, people, part, system
#   told_me, how_much, worry_about, looks_like, talking_about, two_years
